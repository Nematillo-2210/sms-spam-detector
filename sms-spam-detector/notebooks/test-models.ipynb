# %%
import joblib as jl

# %%
bayes_model = jl.load('../models/naive_bayes_pipeline.pkl')
log_reg_model = jl.load('../models/log_reg_pipeline.pkl')
knn_model = jl.load('../models/knn_pipeline.pkl')

# %%
tricky_text = ["Hey man, do you have any cash I can borrow for the vending machine?"]

# %%
print(f"Naive Bayes thinks it is: {bayes_model.predict(tricky_text)[0]}")
print(f"Logistic Regression thinks it is: {log_reg_model.predict(tricky_text)[0]}")
print(f"KNN thinks it is: {knn_model.predict(tricky_text)[0]}")
# Out:
# Naive Bayes thinks it is: ham
# Logistic Regression thinks it is: ham
# KNN thinks it is: ham
